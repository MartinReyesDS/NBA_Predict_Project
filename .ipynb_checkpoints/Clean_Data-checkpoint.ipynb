# %% [markdown]
# # CLEAN DATA Notebook
#
# - Google [Docs](https://docs.google.com/document/d/1pvpaBkCJLoyjcH9gHBvy7lUrq6cec-lAayX1MiGizMs/edit)

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('data/unclean_data.csv').iloc[:,1:]

df['Date'] = pd.to_datetime(df['Date'])
# rename columns
df.rename(columns={'\xa0':'Home','eFG%.1':'D-eFG%.1','TOV%.1':'D-TOV%.1','DRB%':'D-DRB%',
                   'FT/FGA.1':'D-FT/FGA.1','W/L':'Win','Tm':'TmPts','Opp.1':'OppPts'}, inplace = True)

df.drop(df.columns[[33,38]], axis=1, inplace=True)

df['Home'] =  df['Home'].fillna(1)

df.dropna(axis=0, inplace=True)

df.replace(to_replace ='@', value = 0, inplace =True)

df.replace(to_replace ={'Win': {'W': 1, 'L': 0}}, inplace =True)

df['Win'].value_counts()
# Out:
# 1    13118
# 0    13118
# Name: Win, dtype: int64

# %%
df.head()
# Out:
#      G       Date  Home  Opp  Win  TmPts  OppPts    FG   FGA    FG%   3P  \
# 0  1.0 2009-10-28     1  IND    1  120.0   109.0  46.0  87.0  0.529  7.0
# 1  2.0 2009-10-30     1  WAS    1  100.0    89.0  32.0  78.0  0.410  5.0
# 2  3.0 2009-11-01     0  LAL    0  110.0   118.0  40.0  89.0  0.449  7.0
# 3  4.0 2009-11-03     0  POR    1   97.0    91.0  37.0  80.0  0.463  5.0
# 4  5.0 2009-11-04     0  SAC    1  113.0   105.0  46.0  85.0  0.541  6.0
#
#     3PA    3P%    FT   FTA    FT%   ORB   TRB   AST   STL   BLK   TOV    PF  \
# 0  12.0  0.583  21.0  29.0  0.724   8.0  35.0  30.0  16.0   6.0  10.0  25.0
# 1  20.0  0.250  31.0  34.0  0.912  11.0  47.0  18.0   5.0   7.0  12.0  24.0
# 2  23.0  0.304  23.0  26.0  0.885  14.0  40.0  21.0   8.0   3.0  19.0  21.0
# 3  15.0  0.333  18.0  22.0  0.818  11.0  46.0  21.0   4.0   7.0  11.0  15.0
# 4  16.0  0.375  15.0  19.0  0.789  12.0  47.0  17.0   2.0  10.0  16.0  20.0
#
# ...

# %%
df.set_index('Date', inplace=True)

# %%
df['Year'] = df.index.year
df['Month'] = df.index.month
# df['Day'] = df.index.day
df['Yr_M'] = df[['Year', 'Month']].apply(tuple, axis=1)
df['Month_to_group'] = df['Month'].replace(to_replace ={10: 11, 4: 3})
df.head(5)
# Out:
#               G  Home  Opp  Win  TmPts  OppPts    FG   FGA    FG%   3P   3PA  \
# Date
# 2009-10-28  1.0     1  IND    1  120.0   109.0  46.0  87.0  0.529  7.0  12.0
# 2009-10-30  2.0     1  WAS    1  100.0    89.0  32.0  78.0  0.410  5.0  20.0
# 2009-11-01  3.0     0  LAL    0  110.0   118.0  40.0  89.0  0.449  7.0  23.0
# 2009-11-03  4.0     0  POR    1   97.0    91.0  37.0  80.0  0.463  5.0  15.0
# 2009-11-04  5.0     0  SAC    1  113.0   105.0  46.0  85.0  0.541  6.0  16.0
#
#               3P%    FT   FTA    FT%   ORB   TRB   AST   STL   BLK   TOV  \
# Date
# 2009-10-28  0.583  21.0  29.0  0.724   8.0  35.0  30.0  16.0   6.0  10.0
# 2009-10-30  0.250  31.0  34.0  0.912  11.0  47.0  18.0   5.0   7.0  12.0
# 2009-11-01  0.304  23.0  26.0  0.885  14.0  40.0  21.0   8.0   3.0  19.0
# 2009-11-03  0.333  18.0  22.0  0.818  11.0  46.0  21.0   4.0   7.0  11.0
# 2009-11-04  0.375  15.0  19.0  0.789  12.0  47.0  17.0   2.0  10.0  16.0
#
# ...

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ### Aggregate Stats

# %%
month_stats_df.index
# Out:
# MultiIndex([(2009, 11, 'ATL'),
#             (2009, 11, 'BOS'),
#             (2009, 11, 'CHA'),
#             (2009, 11, 'CHI'),
#             (2009, 11, 'CLE'),
#             (2009, 11, 'DAL'),
#             (2009, 11, 'DEN'),
#             (2009, 11, 'DET'),
#             (2009, 11, 'GSW'),
#             (2009, 11, 'HOU'),
#             ...
#             (2020,  8, 'OKC'),
#             (2020,  8, 'ORL'),
#             (2020,  8, 'PHI'),
#             (2020,  8, 'PHO'),
#             (2020,  8, 'POR'),
#             (2020,  8, 'SAC'),
#             (2020,  8, 'SAS'),
#             (2020,  8, 'TOR'),
#             (2020,  8, 'UTA'),
#             (2020,  8, 'WAS')],
#            names=['Year', 'Month_to_group', 'Team'], length=1658)

# %%
month_stats_df = df.groupby(['Year','Month_to_group','Team']).agg(['mean'])
month_stats_df['Month'] = month_stats_df['Month'].round()
# month_stats_df['Year'] = month_stats_df.index[0.year
# month_stats_df['Yr_M'] = month_stats_df[['Year', 'Month']].apply(tuple, axis=1)
month_stats_df.head(500)
# Out:
#                              G      Home       Win       TmPts      OppPts  \
#                           mean      mean      mean        mean        mean
# Year Month_to_group Team
# 2009 11             ATL    9.0  0.470588  0.705882  102.411765   97.470588
#                     BOS    9.0  0.588235  0.764706   99.882353   91.294118
#                     CHA    8.5  0.500000  0.437500   88.187500   87.937500
#                     CHI    8.0  0.333333  0.400000   91.400000   97.600000
#                     CLE    9.0  0.470588  0.705882   99.058824   94.588235
#                     DAL    9.5  0.444444  0.722222  103.388889   97.333333
#                     DEN    9.0  0.470588  0.705882  109.176471  102.705882
#                     DET    9.0  0.470588  0.352941   92.529412   95.000000
#                     GSW    8.5  0.437500  0.375000  109.562500  112.375000
#                     HOU    9.0  0.470588  0.529412  102.058824  101.294118
# ...

# %%
df_game_logs = pd.concat([df.iloc[:,:5], df.iloc[:,-5:-1]], axis=1)
df_game_logs.head(10)
# Out:
#         Date     G  Home  Opp  Win Team  Year  Month  Day
# 0 2009-10-28   1.0     1  IND    1  ATL  2009     10   28
# 1 2009-10-30   2.0     1  WAS    1  ATL  2009     10   30
# 2 2009-11-01   3.0     0  LAL    0  ATL  2009     11    1
# 3 2009-11-03   4.0     0  POR    1  ATL  2009     11    3
# 4 2009-11-04   5.0     0  SAC    1  ATL  2009     11    4
# 5 2009-11-06   6.0     0  CHA    0  ATL  2009     11    6
# 6 2009-11-07   7.0     1  DEN    1  ATL  2009     11    7
# 7 2009-11-11   8.0     0  NYK    1  ATL  2009     11   11
# 8 2009-11-13   9.0     0  BOS    1  ATL  2009     11   13
# 9 2009-11-14  10.0     1  NOH    1  ATL  2009     11   14

# %%
df_game_logs.merge(month_stats_df, right_on=['Month'])
# Out:
# ------------------------------------------------------
# TypeError            Traceback (most recent call last)
# <ipython-input-268-7405073e1612> in <module>
# ----> 1 df_game_logs.merge(month_stats_df, right_on=['Month'])
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ...

# %%
df1 = pd.DataFrame({'W': ['W', 'L', 'W'],
                      'Year': ['1','1','1'],
                      'Month': ['1', '1', '1']})
df2 = pd.DataFrame({'Year': ['1'],
                    'Month': ['1'],
                      'stat': [32]})

# %%
df1
# Out:
#    W Year Month
# 0  W    1     1
# 1  L    1     1
# 2  W    1     1

# %%
df2
# Out:
#   Year Month  stat
# 0    1     1    32

# %%
df1.merge(df2)
# Out:
#    W Year Month  stat
# 0  W    1     1    32
# 1  L    1     1    32
# 2  W    1     1    32
