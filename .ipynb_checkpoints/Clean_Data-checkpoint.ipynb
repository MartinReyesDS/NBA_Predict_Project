# %% [markdown]
# # CLEAN DATA Notebook

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('data/unclean_data.csv').iloc[:,1:]
df.head(100)
# Out:
#        G        Date       Opp  W/L     Tm  Opp.1    FG    FGA    FG%    3P  \
# 0    1.0  2009-10-28  NaN  IND    W  120.0  109.0  46.0   87.0  0.529   7.0
# 1    2.0  2009-10-30  NaN  WAS    W  100.0   89.0  32.0   78.0  0.410   5.0
# 2    3.0  2009-11-01    @  LAL    L  110.0  118.0  40.0   89.0  0.449   7.0
# 3    4.0  2009-11-03    @  POR    W   97.0   91.0  37.0   80.0  0.463   5.0
# 4    5.0  2009-11-04    @  SAC    W  113.0  105.0  46.0   85.0  0.541   6.0
# 5    6.0  2009-11-06    @  CHA    L   83.0  103.0  33.0   83.0  0.398   2.0
# 6    7.0  2009-11-07  NaN  DEN    W  125.0  100.0  45.0   87.0  0.517   8.0
# 7    8.0  2009-11-11    @  NYK    W  114.0  101.0  44.0   81.0  0.543   6.0
# 8    9.0  2009-11-13    @  BOS    W   97.0   86.0  38.0   84.0  0.452   4.0
# 9   10.0  2009-11-14  NaN  NOH    W  121.0   98.0  48.0   88.0  0.545   7.0
# 10  11.0  2009-11-16  NaN  POR    W   99.0   95.0  39.0   91.0  0.429   5.0
# ...

# %%
print(df.shape)
df.info()
# Out:
# (26458, 43)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26458 entries, 0 to 26457
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   G         24118 non-null  float64
#  1   Date      24118 non-null  object
#  2             12059 non-null  object
#  3   Opp       24118 non-null  object
#  4   W/L       24118 non-null  object
#  5   Tm        24118 non-null  float64
#  6   Opp.1     24118 non-null  float64
#  7   FG        24118 non-null  float64
#  8   FGA       24118 non-null  float64
#  9   FG%       24118 non-null  float64
#  10  3P        24118 non-null  float64
#  11  3PA       24118 non-null  float64
#  12  3P%       24118 non-null  float64
#  13  FT        24118 non-null  float64
#  14  FTA       24118 non-null  float64
#  15  FT%       24118 non-null  float64
#  16  ORB       24118 non-null  float64
#  17  TRB       24118 non-null  float64
#  18  AST       24118 non-null  float64
# ...

# %%
# import unclean data
df = pd.read_csv('data/unclean_data.csv').iloc[:,1:]
# rename columns for Off. Four Factors and Def. Four Factors

# rename column with ‘@’s

# add the home column (1 for home, 0 for away)

# remove blank columns

# remove rows with None's, df.dropna(how='all')

# change data types (datetime, int, float)



# pseudocode for aggregating stats

# group by (month and year) and by team, and aggregate the stats columns, join on date
# on final_df, we want a dataframe with win/loss (target) column, game_log (maybe date, home, OPP, scores), aggregated stats for team that month,
